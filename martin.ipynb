# %%
import pandas as pd
import numpy as np

# %%
col_names = ["empty","T-Day","T-Month","T-Year", "Code", "No", "R-Day","R-Month","R-Year",
         "Origin Court", "Origin Code", "Origin No", "Origin Year", "Specific Case Type",
         "Judge 1", "Judge 2", "Judge 3", "Judge 4", "Judge 5", "Judge 6", "Judge 7", 
         "Case coming for", "Case OutCome", "Reason of adjournment", "N-Day","N-Month",
         "N-Year","P-M", "P-F","P-Org.", "D-M", "D-F", "D-Org.", "Legal Rep", "Witness-P", "Witness-D",
         "Crim-Custody","Other Details"]

# %%
sample_data = pd.read_excel("data/sample_data.xlsx", names = col_names)

# %%
sample_data.head()
# Out:
#    empty                                    T-Day T-Month T-Year  \
# 0    NaN  Court station name: \n(Entry required.)     NaN    NaN
# 1    NaN                                      NaN     NaN    NaN
# 2    NaN               \nToday's date\n\n\n\n\n\n     NaN    NaN
# 3    NaN                                      Day   Month   Year
# 4    NaN                                        3     Apr   2023
#
#                                            Code    No R-Day R-Month R-Year  \
# 0                                   A. N. Other   NaN   NaN     NaN    NaN
# 1                                           NaN   NaN   NaN     NaN    NaN
# 2  \nCase Number  and date of Registration)\n\n   NaN   NaN     NaN    NaN
# 3                                          Code   No.   Day   Month   Year
# 4                                          QRCR  E642     3     Apr   2023
#
#                                         Origin Court  ...  P-F P-Org.  \
# ...

# %%
sample_data.drop(index=range(0, 4), inplace=True)

# %%
sample_data.head(15)
# Out:
#     empty T-Day T-Month T-Year      Code     No R-Day R-Month R-Year  \
# 4     NaN     3     Apr   2023      QRCR   E642     3     Apr   2023
# 5     NaN     3     Apr   2023      QRCR  E1411    31     Oct   2022
# 6     NaN     3     Apr   2023      QRCR   E649     3     Apr   2023
# 7     NaN     3     Apr   2023      QRCR   E638     3     Apr   2023
# 8     NaN     3     Apr   2023  QRCRMISC   E109     3     Apr   2023
# 9     NaN     3     Apr   2023      QRCR   E637     3     Apr   2023
# 10    NaN     3     Apr   2023      QRCR   E639     3     Apr   2023
# 11    NaN     3     Apr   2023      QRCR   E643     3     Apr   2023
# 12    NaN     3     Apr   2023  QRCRMISC   E107     3     Apr   2023
# 13    NaN     3     Apr   2023      QRCR     34     6     Jan   2020
# 14    NaN     3     Apr   2023      QRCR   E361    14     Feb   2023
# 15    NaN     3     Apr   2023      QRCR   E481     6     Mar   2023
# 16    NaN     3     Apr   2023      QRCR   E480     6     Mar   2023
# ...

# %%
sample_data.reset_index(drop=True, inplace=True)

# %%
sample_data.head(15)
# Out:
#     empty T-Day T-Month T-Year      Code     No R-Day R-Month R-Year  \
# 0     NaN     3     Apr   2023      QRCR   E642     3     Apr   2023
# 1     NaN     3     Apr   2023      QRCR  E1411    31     Oct   2022
# 2     NaN     3     Apr   2023      QRCR   E649     3     Apr   2023
# 3     NaN     3     Apr   2023      QRCR   E638     3     Apr   2023
# 4     NaN     3     Apr   2023  QRCRMISC   E109     3     Apr   2023
# 5     NaN     3     Apr   2023      QRCR   E637     3     Apr   2023
# 6     NaN     3     Apr   2023      QRCR   E639     3     Apr   2023
# 7     NaN     3     Apr   2023      QRCR   E643     3     Apr   2023
# 8     NaN     3     Apr   2023  QRCRMISC   E107     3     Apr   2023
# 9     NaN     3     Apr   2023      QRCR     34     6     Jan   2020
# 10    NaN     3     Apr   2023      QRCR   E361    14     Feb   2023
# 11    NaN     3     Apr   2023      QRCR   E481     6     Mar   2023
# 12    NaN     3     Apr   2023      QRCR   E480     6     Mar   2023
# ...

# %%
sample_data.drop(columns=["empty"], inplace=True)

# %%
# create the column today days
sample_data["Today's Date"] = sample_data["T-Day"].astype(str) + "-" + sample_data["T-Month"] + "-" + sample_data["T-Year"].astype(str)

# %%
# concatenate t-dates
sample_data.head()
# Out:
#   T-Day T-Month T-Year      Code     No R-Day R-Month R-Year Origin Court  \
# 0     3     Apr   2023      QRCR   E642     3     Apr   2023          NaN
# 1     3     Apr   2023      QRCR  E1411    31     Oct   2022          NaN
# 2     3     Apr   2023      QRCR   E649     3     Apr   2023          NaN
# 3     3     Apr   2023      QRCR   E638     3     Apr   2023          NaN
# 4     3     Apr   2023  QRCRMISC   E109     3     Apr   2023          NaN
#
#   Origin Code  ... P-Org.  D-M  D-F D-Org. Legal Rep Witness-P Witness-D  \
# 0         NaN  ...      1    1  NaN    NaN        No       NaN       NaN
# 1         NaN  ...      1    1  NaN    NaN        No       NaN         1
# 2         NaN  ...      1    1  NaN    NaN        No       NaN       NaN
# 3         NaN  ...      1    1  NaN    NaN        No       NaN       NaN
# 4         NaN  ...      1  NaN    2    NaN        No       NaN       NaN
#
#   Crim-Custody Other Details Today's Date
# ...

# %%
# Convert to date
sample_data["Today's Date"] = pd.to_datetime(sample_data["Today's Date"], format='%d-%b-%Y')

# %%
sample_data.dtypes
# Out:
# T-Day                            object
# T-Month                          object
# T-Year                           object
# Code                             object
# No                               object
# R-Day                            object
# R-Month                          object
# R-Year                           object
# Origin Court                     object
# Origin Code                      object
# Origin No                        object
# Origin Year                      object
# Specific Case Type               object
# Judge 1                          object
# Judge 2                          object
# Judge 3                          object
# Judge 4                          object
# Judge 5                          object
# Judge 6                          object
# Judge 7                          object
# Case coming for                  object
# Case OutCome                     object
# Reason of adjournment            object
# ...

# %%
sample_data.drop(columns=["T-Day", "T-Month", "T-Year"], inplace=True)

# %%
sample_data.head()
# Out:
#        Code     No R-Day R-Month R-Year Origin Court Origin Code Origin No  \
# 0      QRCR   E642     3     Apr   2023          NaN         NaN       NaN
# 1      QRCR  E1411    31     Oct   2022          NaN         NaN       NaN
# 2      QRCR   E649     3     Apr   2023          NaN         NaN       NaN
# 3      QRCR   E638     3     Apr   2023          NaN         NaN       NaN
# 4  QRCRMISC   E109     3     Apr   2023          NaN         NaN       NaN
#
#   Origin Year                                 Specific Case Type  ... P-Org.  \
# 0         NaN  Burglary, housebreaking, entering dwelling-hou...  ...      1
# 1         NaN  Burglary, housebreaking, entering dwelling-hou...  ...      1
# 2         NaN  Possession of narcotic drugs and psychotropic ...  ...      1
# 3         NaN  Grievous harm, maim, assault causing actual bo...  ...      1
# 4         NaN                 Criminal Miscellaneous Application  ...      1
#
# ...

# %%
# change the positon of a new-column
sample_data.insert(0, "Today's Date", sample_data.pop("Today's Date"))

# %%
sample_data.head()
# Out:
#   Today's Date      Code     No R-Day R-Month R-Year Origin Court Origin Code  \
# 0   2023-04-03      QRCR   E642     3     Apr   2023          NaN         NaN
# 1   2023-04-03      QRCR  E1411    31     Oct   2022          NaN         NaN
# 2   2023-04-03      QRCR   E649     3     Apr   2023          NaN         NaN
# 3   2023-04-03      QRCR   E638     3     Apr   2023          NaN         NaN
# 4   2023-04-03  QRCRMISC   E109     3     Apr   2023          NaN         NaN
#
#   Origin No Origin Year  ...  P-F P-Org.  D-M  D-F D-Org. Legal Rep Witness-P  \
# 0       NaN         NaN  ...  NaN      1    1  NaN    NaN        No       NaN
# 1       NaN         NaN  ...  NaN      1    1  NaN    NaN        No       NaN
# 2       NaN         NaN  ...  NaN      1    1  NaN    NaN        No       NaN
# 3       NaN         NaN  ...  NaN      1    1  NaN    NaN        No       NaN
# 4       NaN         NaN  ...  NaN      1  NaN    2    NaN        No       NaN
#
# ...

# %%
sample_data["Registration Date"] = sample_data["R-Day"].astype(str) + "-" + sample_data["R-Month"] + "-" + sample_data["R-Year"].astype(str)

# %%
sample_data.tail()
# Out:
#      Today's Date        Code    No R-Day R-Month R-Year Origin Court  \
# 2152   2023-04-28  QRSUCCMISC  E085    19     Apr   2023          NaN
# 2153   2023-04-28  QRSUCCMISC  E074     6     Apr   2023          NaN
# 2154   2023-04-28        QRCC  E216    28     Apr   2023          NaN
# 2155   2023-04-28   QRELCMISC  E009    27     Apr   2023          NaN
# 2156   2023-04-28        QRCC    24    24     Jan   2020          NaN
#
#      Origin Code Origin No Origin Year  ... P-Org.  D-M  D-F D-Org. Legal Rep  \
# 2152         NaN       NaN         NaN  ...    NaN    1  NaN    NaN       Yes
# 2153         NaN       NaN         NaN  ...    NaN  NaN  NaN    NaN        No
# 2154         NaN       NaN         NaN  ...    NaN    2    1    NaN       Yes
# 2155         NaN       NaN         NaN  ...    NaN  NaN    1    NaN        No
# 2156         NaN       NaN         NaN  ...    NaN    1  NaN    NaN       Yes
#
#      Witness-P Witness-D Crim-Custody  \
# ...

# %%
# Convert to date
sample_data["Registration Date"] = pd.to_datetime(sample_data["Registration Date"], format='%d-%b-%Y')

# %%
sample_data.drop(columns=["R-Day", "R-Month"], inplace=True)

# %%
# change the positon of a new-column
sample_data.insert(1, "Registration Date", sample_data.pop("Registration Date"))

# %%
sample_data["Case Number"] = sample_data["Code"].astype(str) + "/" + sample_data["No"].astype(str) + "/" + sample_data["R-Year"].astype(str)

# %%
sample_data.tail()
# Out:
#      Today's Date Registration Date        Code    No R-Year Origin Court  \
# 2152   2023-04-28        2023-04-19  QRSUCCMISC  E085   2023          NaN
# 2153   2023-04-28        2023-04-06  QRSUCCMISC  E074   2023          NaN
# 2154   2023-04-28        2023-04-28        QRCC  E216   2023          NaN
# 2155   2023-04-28        2023-04-27   QRELCMISC  E009   2023          NaN
# 2156   2023-04-28        2020-01-24        QRCC    24   2020          NaN
#
#      Origin Code Origin No Origin Year                    Specific Case Type  \
# 2152         NaN       NaN         NaN             Miscellaneous Succession
# 2153         NaN       NaN         NaN             Miscellaneous Succession
# 2154         NaN       NaN         NaN                      Liquidated Claim
# 2155         NaN       NaN         NaN  Environmental and Land Miscellaneous
# 2156         NaN       NaN         NaN                      Commercial Suits
#
# ...

# %%
# change the positon of a new-column
sample_data.insert(2, "Case Number", sample_data.pop("Case Number"))

# %%
sample_data.drop(columns=["Code", "No", "R-Year"], inplace=True)

# %%
sample_data.tail()
# Out:
#      Today's Date Registration Date           Case Number Origin Court  \
# 2152   2023-04-28        2023-04-19  QRSUCCMISC/E085/2023          NaN
# 2153   2023-04-28        2023-04-06  QRSUCCMISC/E074/2023          NaN
# 2154   2023-04-28        2023-04-28        QRCC/E216/2023          NaN
# 2155   2023-04-28        2023-04-27   QRELCMISC/E009/2023          NaN
# 2156   2023-04-28        2020-01-24          QRCC/24/2020          NaN
#
#      Origin Code Origin No Origin Year                    Specific Case Type  \
# 2152         NaN       NaN         NaN             Miscellaneous Succession
# 2153         NaN       NaN         NaN             Miscellaneous Succession
# 2154         NaN       NaN         NaN                      Liquidated Claim
# 2155         NaN       NaN         NaN  Environmental and Land Miscellaneous
# 2156         NaN       NaN         NaN                      Commercial Suits
#
#             Judge 1 Judge 2  ...  P-F P-Org.  D-M  D-F D-Org. Legal Rep  \
# ...

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2157 entries, 0 to 2156
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Today's Date           2157 non-null   datetime64[ns]
#  1   Registration Date      2157 non-null   datetime64[ns]
#  2   Case Number            2157 non-null   object
#  3   Origin Court           0 non-null      object
#  4   Origin Code            0 non-null      object
#  5   Origin No              0 non-null      object
#  6   Origin Year            0 non-null      object
#  7   Specific Case Type     2157 non-null   object
#  8   Judge 1                2157 non-null   object
#  9   Judge 2                0 non-null      object
#  10  Judge 3                0 non-null      object
#  11  Judge 4                0 non-null      object
#  12  Judge 5                0 non-null      object
#  13  Judge 6                0 non-null      object
# ...

# %%
sample_data.drop(columns=["Origin Court", "Origin Code", "Origin No", "Origin Year", "Judge 2", "Judge 3", "Judge 4", "Judge 5", "Judge 6", "Judge 7"], inplace=True)

# %%
sample_data.head()
# Out:
#   Today's Date Registration Date         Case Number  \
# 0   2023-04-03        2023-04-03      QRCR/E642/2023
# 1   2023-04-03        2022-10-31     QRCR/E1411/2022
# 2   2023-04-03        2023-04-03      QRCR/E649/2023
# 3   2023-04-03        2023-04-03      QRCR/E638/2023
# 4   2023-04-03        2023-04-03  QRCRMISC/E109/2023
#
#                                   Specific Case Type        Judge 1  \
# 0  Burglary, housebreaking, entering dwelling-hou...  Hon A N Other
# 1  Burglary, housebreaking, entering dwelling-hou...        Hon XYZ
# 2  Possession of narcotic drugs and psychotropic ...  Hon A N Other
# 3  Grievous harm, maim, assault causing actual bo...  Hon A N Other
# 4                 Criminal Miscellaneous Application  Hon A N Other
#
#           Case coming for                 Case OutCome Reason of adjournment  \
# 0                    Plea  Mention date set (in court)                   NaN
# 1                 Hearing                  Adjournment    Advocate not ready
# ...

# %%
sample_data["Judicial Officer"] = sample_data["Judge 1"].astype(str)

# %%
sample_data.head()
# Out:
#   Today's Date Registration Date         Case Number  \
# 0   2023-04-03        2023-04-03      QRCR/E642/2023
# 1   2023-04-03        2022-10-31     QRCR/E1411/2022
# 2   2023-04-03        2023-04-03      QRCR/E649/2023
# 3   2023-04-03        2023-04-03      QRCR/E638/2023
# 4   2023-04-03        2023-04-03  QRCRMISC/E109/2023
#
#                                   Specific Case Type        Judge 1  \
# 0  Burglary, housebreaking, entering dwelling-hou...  Hon A N Other
# 1  Burglary, housebreaking, entering dwelling-hou...        Hon XYZ
# 2  Possession of narcotic drugs and psychotropic ...  Hon A N Other
# 3  Grievous harm, maim, assault causing actual bo...  Hon A N Other
# 4                 Criminal Miscellaneous Application  Hon A N Other
#
#           Case coming for                 Case OutCome Reason of adjournment  \
# 0                    Plea  Mention date set (in court)                   NaN
# 1                 Hearing                  Adjournment    Advocate not ready
# ...

# %%
sample_data.insert(4, "Judicial Officer", sample_data.pop("Judicial Officer"))

# %%
sample_data.head()
# Out:
#   Today's Date Registration Date         Case Number  \
# 0   2023-04-03        2023-04-03      QRCR/E642/2023
# 1   2023-04-03        2022-10-31     QRCR/E1411/2022
# 2   2023-04-03        2023-04-03      QRCR/E649/2023
# 3   2023-04-03        2023-04-03      QRCR/E638/2023
# 4   2023-04-03        2023-04-03  QRCRMISC/E109/2023
#
#                                   Specific Case Type Judicial Officer  \
# 0  Burglary, housebreaking, entering dwelling-hou...    Hon A N Other
# 1  Burglary, housebreaking, entering dwelling-hou...          Hon XYZ
# 2  Possession of narcotic drugs and psychotropic ...    Hon A N Other
# 3  Grievous harm, maim, assault causing actual bo...    Hon A N Other
# 4                 Criminal Miscellaneous Application    Hon A N Other
#
#          Judge 1         Case coming for                 Case OutCome  \
# 0  Hon A N Other                    Plea  Mention date set (in court)
# 1        Hon XYZ                 Hearing                  Adjournment
# ...

# %%
sample_data.drop(columns=["Judge 1"], inplace=True)

# %%
sample_data.head()
# Out:
#   Today's Date Registration Date         Case Number  \
# 0   2023-04-03        2023-04-03      QRCR/E642/2023
# 1   2023-04-03        2022-10-31     QRCR/E1411/2022
# 2   2023-04-03        2023-04-03      QRCR/E649/2023
# 3   2023-04-03        2023-04-03      QRCR/E638/2023
# 4   2023-04-03        2023-04-03  QRCRMISC/E109/2023
#
#                                   Specific Case Type Judicial Officer  \
# 0  Burglary, housebreaking, entering dwelling-hou...    Hon A N Other
# 1  Burglary, housebreaking, entering dwelling-hou...          Hon XYZ
# 2  Possession of narcotic drugs and psychotropic ...    Hon A N Other
# 3  Grievous harm, maim, assault causing actual bo...    Hon A N Other
# 4                 Criminal Miscellaneous Application    Hon A N Other
#
#           Case coming for                 Case OutCome Reason of adjournment  \
# 0                    Plea  Mention date set (in court)                   NaN
# ...

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2157 entries, 0 to 2156
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Today's Date           2157 non-null   datetime64[ns]
#  1   Registration Date      2157 non-null   datetime64[ns]
#  2   Case Number            2157 non-null   object
#  3   Specific Case Type     2157 non-null   object
#  4   Judicial Officer       2157 non-null   object
#  5   Case coming for        2157 non-null   object
#  6   Case OutCome           2157 non-null   object
#  7   Reason of adjournment  156 non-null    object
#  8   N-Day                  1639 non-null   object
#  9   N-Month                1639 non-null   object
#  10  N-Year                 1639 non-null   object
#  11  P-M                    539 non-null    object
#  12  P-F                    248 non-null    object
#  13  P-Org.                 1425 non-null   object
# ...

# %%
sample_data["Next Date"] = sample_data["N-Day"].astype(str)+'-'+sample_data["N-Month"].astype(str)+'-'+sample_data["N-Year"].astype(str)

# %%
sample_data.head()
# Out:
#   Today's Date Registration Date         Case Number  \
# 0   2023-04-03        2023-04-03      QRCR/E642/2023
# 1   2023-04-03        2022-10-31     QRCR/E1411/2022
# 2   2023-04-03        2023-04-03      QRCR/E649/2023
# 3   2023-04-03        2023-04-03      QRCR/E638/2023
# 4   2023-04-03        2023-04-03  QRCRMISC/E109/2023
#
#                                   Specific Case Type Judicial Officer  \
# 0  Burglary, housebreaking, entering dwelling-hou...    Hon A N Other
# 1  Burglary, housebreaking, entering dwelling-hou...          Hon XYZ
# 2  Possession of narcotic drugs and psychotropic ...    Hon A N Other
# 3  Grievous harm, maim, assault causing actual bo...    Hon A N Other
# 4                 Criminal Miscellaneous Application    Hon A N Other
#
#           Case coming for                 Case OutCome Reason of adjournment  \
# 0                    Plea  Mention date set (in court)                   NaN
# ...

# %%
# Convert to date
sample_data["Next Date"] = pd.to_datetime(sample_data["Next Date"], format='%d-%m-%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Convert to date
# ----> 2 sample_data["Next Date"] = pd.to_datetime(sample_data["Next Date"], format='%d-%m-%Y')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1064, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1062             result = arg.tz_localize(tz)
#    1063 elif isinstance(arg, ABCSeries):
# -> 1064     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1065     if not cache_array.empty:
#    1066         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:229, in _maybe_cache(arg, format, cache, convert_listlike)
#     227 unique_dates = unique(arg)
#     228 if len(unique_dates) < len(arg):
# ...

# %%
# Convert to date
sample_data["Next Date"] = pd.to_datetime(sample_data["Next Date"], format='%d-%b-%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Convert to date
# ----> 2 sample_data["Next Date"] = pd.to_datetime(sample_data["Next Date"], format='%d-%b-%Y')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1064, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1062             result = arg.tz_localize(tz)
#    1063 elif isinstance(arg, ABCSeries):
# -> 1064     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1065     if not cache_array.empty:
#    1066         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:229, in _maybe_cache(arg, format, cache, convert_listlike)
#     227 unique_dates = unique(arg)
#     228 if len(unique_dates) < len(arg):
# ...

# %%
sample_data.drop(columns=["N-Day", "N-Month", "N-Year"], inplace=True)

# %%
sample_data.head()
# Out:
#   Today's Date Registration Date         Case Number  \
# 0   2023-04-03        2023-04-03      QRCR/E642/2023
# 1   2023-04-03        2022-10-31     QRCR/E1411/2022
# 2   2023-04-03        2023-04-03      QRCR/E649/2023
# 3   2023-04-03        2023-04-03      QRCR/E638/2023
# 4   2023-04-03        2023-04-03  QRCRMISC/E109/2023
#
#                                   Specific Case Type Judicial Officer  \
# 0  Burglary, housebreaking, entering dwelling-hou...    Hon A N Other
# 1  Burglary, housebreaking, entering dwelling-hou...          Hon XYZ
# 2  Possession of narcotic drugs and psychotropic ...    Hon A N Other
# 3  Grievous harm, maim, assault causing actual bo...    Hon A N Other
# 4                 Criminal Miscellaneous Application    Hon A N Other
#
#           Case coming for                 Case OutCome Reason of adjournment  \
# 0                    Plea  Mention date set (in court)                   NaN
# ...

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2157 entries, 0 to 2156
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Today's Date           2157 non-null   datetime64[ns]
#  1   Registration Date      2157 non-null   datetime64[ns]
#  2   Case Number            2157 non-null   object
#  3   Specific Case Type     2157 non-null   object
#  4   Judicial Officer       2157 non-null   object
#  5   Case coming for        2157 non-null   object
#  6   Case OutCome           2157 non-null   object
#  7   Reason of adjournment  156 non-null    object
#  8   P-M                    539 non-null    object
#  9   P-F                    248 non-null    object
#  10  P-Org.                 1425 non-null   object
#  11  D-M                    1669 non-null   object
#  12  D-F                    433 non-null    object
#  13  D-Org.                 244 non-null    object
# ...

# %%
sample_data.insert(8, "Next Date", sample_data.pop("Next Date"))

# %%
sample_data.head()
# Out:
#   Today's Date Registration Date         Case Number  \
# 0   2023-04-03        2023-04-03      QRCR/E642/2023
# 1   2023-04-03        2022-10-31     QRCR/E1411/2022
# 2   2023-04-03        2023-04-03      QRCR/E649/2023
# 3   2023-04-03        2023-04-03      QRCR/E638/2023
# 4   2023-04-03        2023-04-03  QRCRMISC/E109/2023
#
#                                   Specific Case Type Judicial Officer  \
# 0  Burglary, housebreaking, entering dwelling-hou...    Hon A N Other
# 1  Burglary, housebreaking, entering dwelling-hou...          Hon XYZ
# 2  Possession of narcotic drugs and psychotropic ...    Hon A N Other
# 3  Grievous harm, maim, assault causing actual bo...    Hon A N Other
# 4                 Criminal Miscellaneous Application    Hon A N Other
#
#           Case coming for                 Case OutCome Reason of adjournment  \
# 0                    Plea  Mention date set (in court)                   NaN
# ...

# %%
sample_data.isna().any()
# Out:
# Today's Date             False
# Registration Date        False
# Case Number              False
# Specific Case Type       False
# Judicial Officer         False
# Case coming for          False
# Case OutCome             False
# Reason of adjournment     True
# Next Date                False
# P-M                       True
# P-F                       True
# P-Org.                    True
# D-M                       True
# D-F                       True
# D-Org.                    True
# Legal Rep                False
# Witness-P                 True
# Witness-D                 True
# Crim-Custody              True
# Other Details             True
# dtype: bool
