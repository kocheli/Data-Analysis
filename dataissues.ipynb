# %% [markdown]
# # What are the different types of data issues?

# %% [markdown]
# * Various types of data issues may occur in an organization when collecting data, combining multiple datasets, receiving data from clients, customers or other departments and inputting data. Some example data issues include;

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
students_data = pd.read_csv("Data/students_data.csv", index_col=0)
students_data.head()
# Out:
#                    names  admission number house balance  english  kiswahili  \
# 0    JERIEL NDEDA, OBURA           13259.0   NaN     NaN     81.0       39.0
# 1  MUKUHA TIMOTHY, KAMAU           13243.0   NaN     NaN     85.0       74.0
# 2             JOB, NGARA           13307.0   NaN     NaN     54.0       49.0
# 3     CHEGE DAVID, KAMAU           13258.0   NaN     NaN     71.0       97.0
# 4    RAMADHAN MUSA, TEPO           13363.0   NaN     NaN     40.0       84.0
#
#    mathematics  science  sst/cre Creative Arts music
# 0         50.0     30.0     59.0           99%   80%
# 1         68.0     49.0     78.0           38%   86%
# 2         53.0     59.0     72.0           86%   62%
# 3         92.0     41.0     81.0           77%   80%
# 4         74.0     82.0     89.0           64%   46%

# %%
students_data
# Out:
#                      names  admission number       house balance  english  \
# 0      JERIEL NDEDA, OBURA           13259.0         NaN     NaN     81.0
# 1    MUKUHA TIMOTHY, KAMAU           13243.0         NaN     NaN     85.0
# 2               JOB, NGARA           13307.0         NaN     NaN     54.0
# 3       CHEGE DAVID, KAMAU           13258.0         NaN     NaN     71.0
# 4      RAMADHAN MUSA, TEPO           13363.0         NaN     NaN     40.0
# ..                     ...               ...         ...     ...      ...
# 142   TIMOTHY NDEDA, OBURA        13322634.0       Elgon       0    -78.0
# 143   MUKUHA JERIEL, NGARA         1932845.0  Cherangani     321     94.0
# 144             JOB, KAMAU         1430232.0       Nandi  43,200     98.0
# 145           CHEGE, KAMAU             159.0       Nandi     NaN    508.0
# 146         RAMADHAN, MUSA              87.0  Cherangani     NaN     81.0
#
#      kiswahili  mathematics  science  sst/cre Creative Arts music
# ...

# %%
students_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 146
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   names             147 non-null    object
#  1   admission number  124 non-null    float64
#  2   house             26 non-null     object
#  3   balance           58 non-null     object
#  4   english           121 non-null    float64
#  5   kiswahili         119 non-null    float64
#  6   mathematics       130 non-null    float64
#  7   science           117 non-null    float64
#  8   sst/cre           132 non-null    float64
#  9   Creative Arts     143 non-null    object
#  10  music             147 non-null    object
# dtypes: float64(6), object(5)
# memory usage: 13.8+ KB

# %%
students_data.tail()
# Out:
#                     names  admission number       house balance  english  \
# 142  TIMOTHY NDEDA, OBURA        13322634.0       Elgon       0    -78.0
# 143  MUKUHA JERIEL, NGARA         1932845.0  Cherangani     321     94.0
# 144            JOB, KAMAU         1430232.0       Nandi  43,200     98.0
# 145          CHEGE, KAMAU             159.0       Nandi     NaN    508.0
# 146        RAMADHAN, MUSA              87.0  Cherangani     NaN     81.0
#
#      kiswahili  mathematics  science  sst/cre Creative Arts music
# 142       40.0         99.0     70.0     49.0           99&   92&
# 143      780.0        420.0     71.0     88.0           56%   76%
# 144       80.0         86.0     64.0     99.0           49%   69%
# 145      409.0         77.0     58.0     56.0           88%   84%
# 146       70.0         64.0    680.0     88.0           76%   72%

# %%
students_data.columns
# Out:
# Index(['names', 'admission number', 'house', 'balance', 'english', 'kiswahili',
#        'mathematics', 'science', 'sst/cre', 'Creative Arts', 'music'],
#       dtype='object')

# %%
students_data.shape
# Out:
# (147, 11)

# %% [markdown]
# ## Incomplete data

# %% [markdown]
# * This is data with missing fields and rows that occurs when no data value is stored for an attribute in an observation. Missing data are a common occurrence and can have a significant effect on the insights that can be drawn from the data.

# %% [markdown]
# ## Duplicated entries

# %% [markdown]
# * Duplicate data is any entry that inadvertently shares data with another entry in a Database, ie a complete carbon copy. Duplicate entries in a dataset are also a common occurrence.

# %%
students_data.duplicated()
# true and false if duplicated and not duplicated respectively
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# Length: 147, dtype: bool

# %%
students_data.duplicated().any()
# Out:
# True

# %%
# variable to store numbe of duplicate
no_true = 0

# loop through a bool series, where true is duplicated and false is not duplicated

for val in students_data.duplicated():
    if (val == True):
        # increment the number of True values by one upon finding a duplicate
        no_true += 1
        
no_true
# Out:
# 8

# %%
# checking the percentage of the data that are duplicate
print(f"{np.round(((no_true/len(students_data)) * 100), 4)}% of the Students Data is duplicated")
# Out:
# 5.4422% of the Students Data is duplicated

# %%
#subset 
students_data.drop_duplicates(subset= None, keep= "first")
# Out:
#                      names  admission number       house balance  english  \
# 0      JERIEL NDEDA, OBURA           13259.0         NaN     NaN     81.0
# 1    MUKUHA TIMOTHY, KAMAU           13243.0         NaN     NaN     85.0
# 2               JOB, NGARA           13307.0         NaN     NaN     54.0
# 3       CHEGE DAVID, KAMAU           13258.0         NaN     NaN     71.0
# 4      RAMADHAN MUSA, TEPO           13363.0         NaN     NaN     40.0
# ..                     ...               ...         ...     ...      ...
# 142   TIMOTHY NDEDA, OBURA        13322634.0       Elgon       0    -78.0
# 143   MUKUHA JERIEL, NGARA         1932845.0  Cherangani     321     94.0
# 144             JOB, KAMAU         1430232.0       Nandi  43,200     98.0
# 145           CHEGE, KAMAU             159.0       Nandi     NaN    508.0
# 146         RAMADHAN, MUSA              87.0  Cherangani     NaN     81.0
#
#      kiswahili  mathematics  science  sst/cre Creative Arts music
# ...

# %%
students_data.duplicated().any()
# Out:
# True

# %%
#subset specifies which column to be included when checking the duplicated.
#Keep refers to the occurance that you want to observe
students_data.drop_duplicates(subset= None, keep= "first", inplace= True)

# %%
students_data.duplicated().any()
# Out:
# False

# %% [markdown]
# #### Duplicates in specific columns
# * unique identifiers should not be duplicated

# %%
admin_col = students_data.duplicated(subset= ["admission number"])
admin_col
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# Length: 139, dtype: bool

# %%
students_data.duplicated(subset= ["admission number"]).any()
# Out:
# True

# %%
num_true = 0
for item in admin_col:
    if (item == True):
        num_true += 1
num_true
# Out:
# 47

# %%
# created a list of shared admissions
shared_admission = []

for index, val in enumerate(admin_col):
    if (val == True):
        shared_admission.append(index)
        
shared_admission
# Out:
# [12,
#  16,
#  28,
#  37,
#  43,
#  44,
#  50,
#  52,
#  61,
#  63,
#  66,
#  70,
#  72,
#  74,
#  75,
#  78,
#  81,
#  82,
#  90,
#  91,
#  93,
#  94,
#  95,
#  100,
#  102,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133]

# %%
len(shared_admission)
# Out:
# 47

# %%
# accessing column admission number by the name of the column
students_data["admission number"]
# Out:
# 0         13259.0
# 1         13243.0
# 2         13307.0
# 3         13258.0
# 4         13363.0
#           ...
# 142    13322634.0
# 143     1932845.0
# 144     1430232.0
# 145         159.0
# 146          87.0
# Name: admission number, Length: 139, dtype: float64

# %% [markdown]
# `df.locc[]` and `df.iloc[]`
# * syntax
# ```
# df.loc[row_label, column_label]
# df.iloc[row_index, column_label]
# ```

# %%
# accessing a single element 
loc_value = students_data.loc[143, "admission number"]
loc_value
# Out:
# 1932845.0

# %%
iloc_value = students_data.iloc[2, 1]
iloc_value
# Out:
# 13307.0

# %%
students_data
# Out:
#                      names  admission number       house balance  english  \
# 0      JERIEL NDEDA, OBURA           13259.0         NaN     NaN     81.0
# 1    MUKUHA TIMOTHY, KAMAU           13243.0         NaN     NaN     85.0
# 2               JOB, NGARA           13307.0         NaN     NaN     54.0
# 3       CHEGE DAVID, KAMAU           13258.0         NaN     NaN     71.0
# 4      RAMADHAN MUSA, TEPO           13363.0         NaN     NaN     40.0
# ..                     ...               ...         ...     ...      ...
# 142   TIMOTHY NDEDA, OBURA        13322634.0       Elgon       0    -78.0
# 143   MUKUHA JERIEL, NGARA         1932845.0  Cherangani     321     94.0
# 144             JOB, KAMAU         1430232.0       Nandi  43,200     98.0
# 145           CHEGE, KAMAU             159.0       Nandi     NaN    508.0
# 146         RAMADHAN, MUSA              87.0  Cherangani     NaN     81.0
#
#      kiswahili  mathematics  science  sst/cre Creative Arts music
# ...

# %%
# selecting a whole row
students_data.loc[10, :]
# Out:
# names               MUGANE JOB, NGATIA
# admission number               13366.0
# house                            Elgon
# balance                         36,466
# english                           57.0
# kiswahili                         66.0
# mathematics                       72.0
# science                           33.0
# sst/cre                           76.0
# Creative Arts                      86%
# music                              79%
# Name: 10, dtype: object

# %%
# selecting mutliple rows
students_data.loc[40:50, :]
# Out:
#                      names  admission number  house balance  english  \
# 40    VICTOR MARTIN, ODUOR           13299.0    NaN     NaN     92.0
# 41  WABWIRE KHAKA, TATYANA           13331.0    NaN     165     49.0
# 42   WAMBANI IAN, ESHITEMI           13244.0    NaN     NaN     78.0
# 43            WARIO, NASRI           13307.0  Elgon      72     65.0
# 44      WINSTON, CHURCHILL           13323.0    NaN      41     94.0
# 45   ABDIRAHAMAN, ABDIHADI           13384.0    NaN     NaN     55.0
# 46          ABIGAEL, KAMAU           13313.0    NaN  29,842     80.0
# 47    ASIF MOHAMMED, IQBAL           13357.0    NaN     NaN     60.0
# 48         BARASA, INYANJI           13315.0    NaN     NaN     73.0
# 49       BANNAFFECT, KOBIA           13255.0    NaN  32,194     45.0
# 50          CALEB, KONANGA           13389.0    NaN     NaN     77.0
#
#     kiswahili  mathematics  science  sst/cre Creative Arts music
# 40       55.0         84.0     34.0     79.0           81%   40%
# ...

# %%
students_data.loc[:, "names"]
# Out:
# 0        JERIEL NDEDA, OBURA
# 1      MUKUHA TIMOTHY, KAMAU
# 2                 JOB, NGARA
# 3         CHEGE DAVID, KAMAU
# 4        RAMADHAN MUSA, TEPO
#                ...
# 142     TIMOTHY NDEDA, OBURA
# 143     MUKUHA JERIEL, NGARA
# 144               JOB, KAMAU
# 145             CHEGE, KAMAU
# 146           RAMADHAN, MUSA
# Name: names, Length: 139, dtype: object

# %%
students_data.iloc[:, 0]
# Out:
# 0        JERIEL NDEDA, OBURA
# 1      MUKUHA TIMOTHY, KAMAU
# 2                 JOB, NGARA
# 3         CHEGE DAVID, KAMAU
# 4        RAMADHAN MUSA, TEPO
#                ...
# 142     TIMOTHY NDEDA, OBURA
# 143     MUKUHA JERIEL, NGARA
# 144               JOB, KAMAU
# 145             CHEGE, KAMAU
# 146           RAMADHAN, MUSA
# Name: names, Length: 139, dtype: object

# %%
# creating a slice
students_data.loc[2:7, "names":"science"]
# Out:
#                    names  admission number house balance  english  kiswahili  \
# 2             JOB, NGARA           13307.0   NaN     NaN     54.0       49.0
# 3     CHEGE DAVID, KAMAU           13258.0   NaN     NaN     71.0       97.0
# 4    RAMADHAN MUSA, TEPO           13363.0   NaN     NaN     40.0       84.0
# 5  MUENDO CICILY, MUTHEU           13283.0   NaN     NaN     43.0       60.0
# 6       IAN MWAI, TOYOTA           13233.0   NaN  23,204     82.0       68.0
# 7    PITA SHEKINAH, WISE           13389.0   NaN     NaN     61.0       81.0
#
#    mathematics  science
# 2         53.0     59.0
# 3         92.0     41.0
# 4         74.0     82.0
# 5         48.0     94.0
# 6         91.0     69.0
# 7         53.0     73.0

# %%
students_data.iloc[1:9, 2:8]
# Out:
#   house balance  english  kiswahili  mathematics  science
# 1   NaN     NaN     85.0       74.0         68.0     49.0
# 2   NaN     NaN     54.0       49.0         53.0     59.0
# 3   NaN     NaN     71.0       97.0         92.0     41.0
# 4   NaN     NaN     40.0       84.0         74.0     82.0
# 5   NaN     NaN     43.0       60.0         48.0     94.0
# 6   NaN  23,204     82.0       68.0         91.0     69.0
# 7   NaN     NaN     61.0       81.0         53.0     73.0
# 8   NaN  24,463     78.0       29.0         50.0     62.0

# %% [markdown]
# #### Duplicates in specific columns.... continued

# %%
# accessing a single row in the shared admission using df.loc
students_data.loc[12, :]
# Out:
# names               ADANGA, JAMES
# admission number          13383.0
# house                         NaN
# balance                       NaN
# english                      61.0
# kiswahili                    59.0
# mathematics                  95.0
# science                      79.0
# sst/cre                      78.0
# Creative Arts                 80%
# music                         82%
# Name: 12, dtype: object

# %%
students_data.loc[94, :]
# Out:
# names               SIUNDU AGATHA, NICOLE
# admission number                  13247.0
# house                                 NaN
# balance                               NaN
# english                              38.0
# kiswahili                            52.0
# mathematics                         100.0
# science                              77.0
# sst/cre                              86.0
# Creative Arts                         62%
# music                                 32%
# Name: 94, dtype: object

# %%
# compare
students_data.loc[students_data["admission number"] == 13383.0]
# Out:
#              names  admission number house balance  english  kiswahili  \
# 11  PRETIE, ARIONA           13383.0   NaN   8,814     82.0       30.0
# 12   ADANGA, JAMES           13383.0   NaN     NaN     61.0       59.0
#
#     mathematics  science  sst/cre Creative Arts music
# 11         79.0     67.0     98.0           62%   79%
# 12         95.0     79.0     78.0           80%   82%

# %%
students_data.loc[students_data["admission number"] == 13247.0]
# Out:
#                     names  admission number house balance  english  kiswahili  \
# 94  SIUNDU AGATHA, NICOLE           13247.0   NaN     NaN     38.0       52.0
#
#     mathematics  science  sst/cre Creative Arts music
# 94        100.0     77.0     86.0           62%   32%

# %%
# changing Pretie admission Number
# Pretie is the first duplicates
# Adanga is the last duplicate
# slicing/ accessing the data based on the value of the column admission number
adanga_index = students_data[students_data["admission number"] == 13383.0].index[1]

# %%
students_data.loc[adanga_index, "admission number"] = 15000

# %%
students_data.loc[11:12, :]
# Out:
#              names  admission number house balance  english  kiswahili  \
# 11  PRETIE, ARIONA           13383.0   NaN   8,814     82.0       30.0
# 12   ADANGA, JAMES           15000.0   NaN     NaN     61.0       59.0
#
#     mathematics  science  sst/cre Creative Arts music
# 11         79.0     67.0     98.0           62%   79%
# 12         95.0     79.0     78.0           80%   82%

# %% [markdown]
# #### Removing Unwanted Observations

# %%
# remove column
students_data.drop(columns = ["house"], inplace = True)

# %% [markdown]
# ###### alternative using axis
# #data,drop(["date", "month", "year"], axis -1, inplace = True)
# ###### axis =1 refers to column while axis =0 refers to rows

# %%
students_data.head(10)
# Out:
#                    names  admission number balance  english  kiswahili  \
# 0    JERIEL NDEDA, OBURA           13259.0     NaN     81.0       39.0
# 1  MUKUHA TIMOTHY, KAMAU           13243.0     NaN     85.0       74.0
# 2             JOB, NGARA           13307.0     NaN     54.0       49.0
# 3     CHEGE DAVID, KAMAU           13258.0     NaN     71.0       97.0
# 4    RAMADHAN MUSA, TEPO           13363.0     NaN     40.0       84.0
# 5  MUENDO CICILY, MUTHEU           13283.0     NaN     43.0       60.0
# 6       IAN MWAI, TOYOTA           13233.0  23,204     82.0       68.0
# 7    PITA SHEKINAH, WISE           13389.0     NaN     61.0       81.0
# 8   MSHINDI DANIEL, OUMA           13367.0  24,463     78.0       29.0
# 9      BRENDA, CHEROTICH           13385.0     NaN     88.0       30.0
#
#    mathematics  science  sst/cre Creative Arts music
# 0         50.0     30.0     59.0           99%   80%
# 1         68.0     49.0     78.0           38%   86%
# ...

# %%
 # remove rows
students_data.drop(index=[3, 5, 7], inplace=True)
students_data.head()
# Out:
#                    names  admission number balance  english  kiswahili  \
# 0    JERIEL NDEDA, OBURA           13259.0     NaN     81.0       39.0
# 1  MUKUHA TIMOTHY, KAMAU           13243.0     NaN     85.0       74.0
# 2             JOB, NGARA           13307.0     NaN     54.0       49.0
# 4    RAMADHAN MUSA, TEPO           13363.0     NaN     40.0       84.0
# 6       IAN MWAI, TOYOTA           13233.0  23,204     82.0       68.0
#
#    mathematics  science  sst/cre Creative Arts music
# 0         50.0     30.0     59.0           99%   80%
# 1         68.0     49.0     78.0           38%   86%
# 2         53.0     59.0     72.0           86%   62%
# 4         74.0     82.0     89.0           64%   46%
# 6         91.0     69.0     81.0           44%   59%

# %%
students_data.tail()
# Out:
#                     names  admission number balance  english  kiswahili  \
# 142  TIMOTHY NDEDA, OBURA        13322634.0       0    -78.0       40.0
# 143  MUKUHA JERIEL, NGARA         1932845.0     321     94.0      780.0
# 144            JOB, KAMAU         1430232.0  43,200     98.0       80.0
# 145          CHEGE, KAMAU             159.0     NaN    508.0      409.0
# 146        RAMADHAN, MUSA              87.0     NaN     81.0       70.0
#
#      mathematics  science  sst/cre Creative Arts music
# 142         99.0     70.0     49.0           99&   92&
# 143        420.0     71.0     88.0           56%   76%
# 144         86.0     64.0     99.0           49%   69%
# 145         77.0     58.0     56.0           88%   84%
# 146         64.0    680.0     88.0           76%   72%

# %%
students_data.drop(index=range(125, 130), inplace=True)

# %%
students_data.tail(20)
# Out:
#                      names  admission number balance  english  kiswahili  \
# 122   Esther Wanagi, Faith               NaN     NaN      NaN       78.0
# 123         Everlyn, Asiko               NaN     NaN      NaN        NaN
# 124        Flora, Waithera               NaN     NaN      NaN        NaN
# 130           Noah, Kandie               NaN     NaN      NaN        NaN
# 131        Pauline, Kagiri               NaN     NaN      NaN        NaN
# 132        Raphael, Katana               NaN     NaN      NaN        NaN
# 133      Sam Ngigi, Samuel               NaN  30,682      NaN        NaN
# 134   Roselynn Kamau, Rose               NaN   5,907      NaN        NaN
# 135  Samuel Gitahi, Mwangi               NaN     NaN      NaN        NaN
# 136         Samuel, Kadima               NaN     NaN      NaN        NaN
# 137         Sasha, Achieng               NaN     NaN      NaN        NaN
# 138            Tess, Yieke               NaN     NaN      NaN        NaN
# ...

# %%
students_data.reset_index(drop=True, inplace=True)

# %%
students_data.tail(40)
# Out:
#                          names  admission number balance  english  kiswahili  \
# 91        TRENT WYCLIFF, MECHA           13313.0     NaN     34.0       97.0
# 92      VALARY ATIENO, ODIMUOR           13358.0     208     65.0       44.0
# 93                WANZA, NIKKY           13345.0     NaN     96.0       92.0
# 94         YASSIN KANGU, KWEYU           13365.0     NaN     46.0       51.0
# 95            ANNABEL, NKIROTE           13285.0  22,244     92.0       68.0
# 96               Barclay, Koin           13232.0     NaN     98.0       84.0
# 97     Christine Karimi, Clare           13259.0     NaN     58.0       65.0
# 98    Daniel Karanja, Gathigia           13387.0   9,382     84.0       70.0
# 99       Faith Kamau, Kithinji           13268.0  28,928     76.0       78.0
# 100                  Mark Tiba           13333.0  42,760     78.0       90.0
# 101           Allan, Ong'ang'a           13134.0   1,295     76.0       44.0
# ...

# %%
sample_data = pd.read_excel("data/sample_data.xlsx", header = 4)

# %%
sample_data.head()
# Out:
#    Unnamed: 0  Day Month  Year      Code    No.  Day.1 Month.1  Year.1  \
# 0         NaN    3   Apr  2023      QRCR   E642      3     Apr    2023
# 1         NaN    3   Apr  2023      QRCR  E1411     31     Oct    2022
# 2         NaN    3   Apr  2023      QRCR   E649      3     Apr    2023
# 3         NaN    3   Apr  2023      QRCR   E638      3     Apr    2023
# 4         NaN    3   Apr  2023  QRCRMISC   E109      3     Apr    2023
#
#    Name of Court  ...   F  Org.  M.1  F.1 Org..1  (Y/N)  P \n(Enter No.)  \
# 0            NaN  ... NaN   1.0  1.0  NaN    NaN     No              NaN
# 1            NaN  ... NaN   1.0  1.0  NaN    NaN     No              NaN
# 2            NaN  ... NaN   1.0  1.0  NaN    NaN     No              NaN
# 3            NaN  ... NaN   1.0  1.0  NaN    NaN     No              NaN
# 4            NaN  ... NaN   1.0  NaN  2.0    NaN     No              NaN
#
#    D\n(Enter No.)  (Enter No.)  (Free text)
# 0             NaN          1.0          NaN
# ...

# %% [markdown]
# ## Invalid Data

# %% [markdown]
# * Data attributes are not conforming with the logical dataset mapping. This includes wrong data types and wrong data formats which in turn interferes with the analysis process. Remember the computer doesn’t understand 95% as a numerical representation but instead as a string.

# %% [markdown]
# ## Conflicting data

# %% [markdown]
# * Occurs when there are same records with different attributes ie there are deviations between data intended to capture the same real-world entity and can mislead any analysis done on it.

# %%
admin_col
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# Length: 139, dtype: bool
